# %% [markdown]
# <a href="https://colab.research.google.com/github/mmsamiei/MS-Thesis-Phase3/blob/master/Models/Montazeri/Montazeri_L-2-2_H-128_Plus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #In the name of God

# %%
import IPython
from google.colab import output

display(IPython.display.Javascript('''
  function ClickConnect(){
    console.log("Working"); 
    document.querySelector("colab-connect-button").click() 
  }
  var connect_timer = setInterval(ClickConnect,60000)
'''))

print("Done.")
# Out:
# Done.

# %%
# !nvidia-smi
# Out:
# Mon Jul 20 07:39:35 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.51.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !git clone https://github.com/mmsamiei/transformers-zirab
# %cd transformers-zirab/
# %pip install .
# Out:
# Cloning into 'transformers-zirab'...
# remote: Enumerating objects: 34926, done.
# remote: Total 34926 (delta 0), reused 0 (delta 0), pack-reused 34926
# Receiving objects: 100% (34926/34926), 25.43 MiB | 9.49 MiB/s, done.
# Resolving deltas: 100% (24151/24151), done.
# /content/transformers-zirab
# Processing /content/transformers-zirab
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers==3.0.2) (1.18.5)
# Collecting tokenizers==0.8.1.rc1
#   Downloading https://files.pythonhosted.org/packages/40/d0/30d5f8d221a0ed981a186c8eb986ce1c94e3a6e87f994eae9f4aa5250217/tokenizers-0.8.1rc1-cp36-cp36m-manylinux1_x86_64.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 2.6MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers==3.0.2) (20.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers==3.0.2) (3.0.12)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers==3.0.2) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers==3.0.2) (4.41.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers==3.0.2) (2019.12.20)
# Collecting sentencepiece!=0.1.92
#   Downloading https://files.pythonhosted.org/packages/d4/a4/d0a884c4300004a78cca907a6ff9a5e9fe4f090f5d95ab341c53d28cbc58/sentencepiece-0.1.91-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 21.8MB/s
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 30.3MB/s
# Requirement already satisfied: dataclasses in /usr/local/lib/python3.6/dist-packages (from transformers==3.0.2) (0.7)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers==3.0.2) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from packaging->transformers==3.0.2) (1.12.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.0.2) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.0.2) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.0.2) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers==3.0.2) (2.10)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==3.0.2) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers==3.0.2) (0.16.0)
# Building wheels for collected packages: transformers, sacremoses
#   Building wheel for transformers (setup.py) ... done
#   Created wheel for transformers: filename=transformers-3.0.2-cp36-none-any.whl size=789366 sha256=dbfc9dbb5c3c7e29e0734eb3a16441037d7e101ea8cd6793b58b0a3f232558fc
#   Stored in directory: /root/.cache/pip/wheels/df/8c/41/d59504f36bccc68fab7ab4a6ba91e9810d1ae946282e7d0c7e
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893260 sha256=6b8b42aa3c1bc414c493d6ab2f684c581c0212e0bf8b3fd0cfff7c4ca127ba17
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built transformers sacremoses
# Installing collected packages: tokenizers, sentencepiece, sacremoses, transformers
# Successfully installed sacremoses-0.0.43 sentencepiece-0.1.91 tokenizers-0.8.1rc1 transformers-3.0.2

# %%
from torch.utils.data import Dataset, DataLoader
import os
import torch
import json
from torch.utils.data.sampler import SubsetRandomSampler
from transformers import AutoTokenizer
import random
import pandas as pd
import logging
import os

import torch
import torch.nn as nn
from torch.nn import functional as F
from torch.utils.data import DataLoader
from torchvision import transforms
from transformers import AutoModel

# %% [markdown]
# # Dataset

# %%
train_file = '/content/drive/My Drive/Thesis/phase-3/hkr_train.csv'
valid_file =  '/content/drive/My Drive/Thesis/phase-3/hkr_valid.csv'
test_seen_file = '/content/drive/My Drive/Thesis/phase-3/hkr_test_seen.csv'
test_unseen_file = '/content/drive/My Drive/Thesis/phase-3/hkr_test_unseen.csv'
last_sentence_file = '/content/drive/My Drive/Thesis/phase-3/last_sentence.csv'
squad_file = '/content/drive/My Drive/Thesis/phase-3/squad.csv'

# %%
enc_tokenizer = AutoTokenizer.from_pretrained('google/bert_uncased_L-2_H-128_A-2')
dec_tokenizer = AutoTokenizer.from_pretrained('google/bert_uncased_L-2_H-128_A-2')
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=382.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=231508.0, style=ProgressStyle(descripti…

# %%
class MyDataset(Dataset):
    """My dataset."""

    def __init__(self, csv_file, frac=1, split_rate=1, max_len=512, sort=True, bound=False):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
        """
        self.dialogues = pd.read_csv(csv_file)
        #self.dialogues.dropna(inplace=True)
        
        self.dialogues.fillna("", inplace=True)
        self.dialogues = self.dialogues[self.dialogues.index % split_rate == 0]

        #self.dialogues = self.dialogues.sample(frac=frac)
        
        if bound:
          len_prt = int(len(self.dialogues) / 5)
          self.dialogues = self.dialogues[ : len_prt]

        s = self.dialogues['response'].apply(dec_tokenizer.encode).apply(len).sort_values().index
        self.dialogues = self.dialogues.reindex(s)

        

        #self.dialogues.dropna(inplace=True)

        self.max_len = max_len


    def __len__(self):
        return len(self.dialogues)

    @staticmethod
    def truncuate_join_pair_sentence(sentence1, sentence2, max_len=510):

        """
        truncuate sentence one from head and sentence two from tail
        Args:
            sentence1 (string): first sentence
            sentence2 (string): seconde sentence
        """
        temp1 = enc_tokenizer.encode(sentence1,add_special_tokens=False)
        temp2 = enc_tokenizer.encode(sentence2,add_special_tokens=False)
        ### two above line may cause warning but no problem because we've handle them below
        logging.getLogger("transformers.tokenization_utils").setLevel(logging.ERROR)
        seq_1 = temp1
        seq_2 = temp2
        num_tokens_to_remove = len(temp1) + len(temp2) + 3 - max_len
        if num_tokens_to_remove > 0 :
            seq_1, seq_2, _ = enc_tokenizer.truncate_sequences(temp1[::-1],temp2, num_tokens_to_remove=num_tokens_to_remove,
                                                               truncation_strategy='longest_first')
            seq_1.reverse()
        result_list = [enc_tokenizer.cls_token_id]+seq_1+[enc_tokenizer.sep_token_id]+seq_2+[enc_tokenizer.sep_token_id]
        token_type_ids = [0] * (len(seq_1) + 2) + [1] * (len(seq_2) + 1)
        return result_list, token_type_ids


    def __getitem__(self, idx):
      
        
        history = self.dialogues.iloc[idx].history
        knowledge = self.dialogues.iloc[idx].knowledge
        response = self.dialogues.iloc[idx].response


        input_pair, input_pair_segments = MyDataset.truncuate_join_pair_sentence(history, knowledge, self.max_len)
                

        input_pair = torch.LongTensor(input_pair)

        input_pair_segments = torch.LongTensor(input_pair_segments)

        response_tensor = torch.LongTensor(dec_tokenizer.encode(response, truncation=True, max_length=128))

        sample = {'input_pair': input_pair,
                  'input_pair_segments': input_pair_segments,
                  'response': response_tensor}

        return sample

# %%
train_dataset = MyDataset(train_file, max_len=128, bound=False)
valid_dataset = MyDataset(valid_file, max_len=128)
test_seen_dataset = MyDataset(test_seen_file, max_len=128)
test_unseen_dataset = MyDataset(test_unseen_file, max_len=128)
print(len(train_dataset))
print(len(valid_dataset))
print(len(test_seen_dataset))
print(len(test_unseen_dataset))
# Out:
# 41489
# 4458
# 2224
# 2075

# %%
print(enc_tokenizer.decode(train_dataset[500]['input_pair']))
print(dec_tokenizer.decode(train_dataset[500]['response']))
# Out:
# [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# [CLS] rail vehicles use tracks and not roads [SEP]

# %%
from tqdm.auto import tqdm

def my_collate_fn(batch):

  len_batch = len(batch)

  
  max_len_input_pair = max([len(data['input_pair']) for data in batch])

  max_len_response = max([len(data['response']) for data in batch])
  
  padding_ind = 0 ## for bert is 0 DON'T THINK BAD IT IS NOT REFACTORING !!!!!!
  result_input_pair = torch.zeros(len_batch, max_len_input_pair)
  result_input_pair_segments = torch.zeros(len_batch, max_len_input_pair)
  result_response = torch.zeros(len_batch, max_len_response)

  for i, data in enumerate(batch):
    p1 = len(data['input_pair'])
    result_input_pair[i, :p1] = data['input_pair']

    p3 = len(data['input_pair_segments'])
    result_input_pair_segments[i, :p3] = data['input_pair_segments']

    p4 = len(data['response'])
    result_response[i, :p4] = data['response']

  return result_input_pair.long(), result_input_pair_segments.long(), result_response.long()

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64,
                                             shuffle=False, collate_fn=my_collate_fn,
                                           num_workers=1)

#valid_sampler = torch.utils.data.SequentialSampler(valid_dataset)
valid_loader = torch.utils.data.DataLoader(valid_dataset, batch_size=64,
                                             shuffle=False, collate_fn=my_collate_fn, num_workers=1)

i = 0 
for batch_idx, batch  in tqdm(enumerate(train_loader)):
  pair_batch, segment_batch, response_batch = batch
  print(pair_batch.shape)
  print(segment_batch.shape)
  print(response_batch.shape)
  print("****")
  i += 1 
  if(i==2):
    break

print(len(train_loader))
print(len(valid_loader))
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# torch.Size([64, 128])
# torch.Size([64, 128])
# torch.Size([64, 6])
# ****
# torch.Size([64, 128])
# torch.Size([64, 128])
# torch.Size([64, 7])
# ****
# 649
# 70

# %% [markdown]
# # Model

# %%
from transformers import EncoderDecoderModel, BertTokenizer

class Model(nn.Module):
  def __init__(self):
    super(Model, self).__init__()

    self.seq2seq = EncoderDecoderModel.from_encoder_decoder_pretrained(
        'google/bert_uncased_L-2_H-128_A-2', 'google/bert_uncased_L-2_H-128_A-2')
    
    # for p in self.seq2seq.encoder.embeddings.parameters():
    #    p.requires_grad = False
    
    # for p in self.seq2seq.decoder.bert.embeddings.parameters():
    #    p.requires_grad = False

  def forward(self, encoder_input, segments_tensors, decoder_input):
    '''
    encoder_input = [batch_size, enc_len]
    segments_tensors = [batch_size, enc_len]
    decoder_input = [batch_size, dec_len]
    '''
    kwargs = {'token_type_ids':segments_tensors}
    outputs = self.seq2seq(input_ids=encoder_input, decoder_input_ids=decoder_input, **kwargs)[0]
    return outputs
  
  def generate(self, encoder_input, segments_tensors, **kwargs):
    ### encoder_input = [len] in int format
    ### segment_tensors = [len]
    encoder_input = encoder_input.unsqueeze(0)
    segments_tensors = segments_tensors.unsqueeze(0)
    
    kwargs ['token_type_ids'] = segments_tensors
    generated = model.seq2seq.generate(input_ids=encoder_input,
        decoder_start_token_id=101,bos_token_id=101,
        eos_token_id=102, **kwargs)

    #### generated = [1, len]
    return generated

# %%
dev = torch.device('cuda')
model = Model().to(dev)

# x = torch.LongTensor(200, 40).random_(1,1000).to(dev)
# print(model(x).shape)


def count_parameters(model): return sum(p.numel() for p in model.parameters() if p.requires_grad)
print(count_parameters(model))
# Out:
# Some weights of the model checkpoint at google/bert_uncased_L-2_H-128_A-2 were not used when initializing BertLMHeadModel: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertLMHeadModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPretraining model).
# - This IS NOT expected if you are initializing BertLMHeadModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertLMHeadModel were not initialized from the model checkpoint at google/bert_uncased_L-2_H-128_A-2 and are newly initialized: ['bert.encoder.layer.0.crossattention.self.query.weight', 'bert.encoder.layer.0.crossattention.self.query.bias', 'bert.encoder.layer.0.crossattention.self.key.weight', 'bert.encoder.layer.0.crossattention.self.key.bias', 'bert.encoder.layer.0.crossattention.self.value.weight', 'bert.encoder.layer.0.crossattention.self.value.bias', 'bert.encoder.layer.0.crossattention.output.dense.weight', 'bert.encoder.layer.0.crossattention.output.dense.bias', 'bert.encoder.layer.0.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.0.crossattention.output.LayerNorm.bias', 'bert.encoder.layer.1.crossattention.self.query.weight', 'bert.encoder.layer.1.crossattention.self.query.bias', 'bert.encoder.layer.1.crossattention.self.key.weight', 'bert.encoder.layer.1.crossattention.self.key.bias', 'bert.encoder.layer.1.crossattention.self.value.weight', 'bert.encoder.layer.1.crossattention.self.value.bias', 'bert.encoder.layer.1.crossattention.output.dense.weight', 'bert.encoder.layer.1.crossattention.output.dense.bias', 'bert.encoder.layer.1.crossattention.output.LayerNorm.weight', 'bert.encoder.layer.1.crossattention.output.LayerNorm.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 8951738

# %% [markdown]
# #Optimizer

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=3e-5)

# %%
from transformers import get_cosine_schedule_with_warmup, get_constant_schedule
scheduler = get_constant_schedule(optimizer)

# %%
lrs = []
for i in tqdm(range(20000)):
  optimizer.step()
  scheduler.step()
  lrs.append(scheduler.get_last_lr()[0])
import matplotlib.pyplot as plt
plt.plot(lrs)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=20000.0), HTML(value='')))

# %% [markdown]
# # Training

# %%
df = pd.read_csv(train_file)
freqs = [1] * dec_tokenizer.vocab_size
for response in tqdm(df['response']):
  tknzd = dec_tokenizer.encode(response)
  for tkn in tknzd:
    freqs[tkn] += 1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=41489.0), HTML(value='')))

# %%
def get_weights(_lambda = 0):
  weights = torch.ones(dec_tokenizer.vocab_size)
  # for idx, freq in enumerate(freqs):
  #   weight = 1 / (freq**_lambda)
  #   weights[idx] = weight
  return weights

# %%
import torch.nn

weight = get_weights().to(dev)

def mahdi_loss(model_output, true_trg, **kwargs):
  '''
  model_output: [batch, len, hidden]
  true_trg: [batch, len]
  '''
  model_output = model_output[:,:-1,:]
  true_trg = true_trg[:,1:]

  # cold
  #T = 1
  #model_output = model_output / T

  if 'easy_training' in kwargs:
    print("Easy training")
    limit_last_tokens = kwargs['easy_training']
    model_output = model_output[:,-limit_last_tokens:,:]
    true_trg = true_trg[:,-limit_last_tokens:]

  batch_len = model_output.shape[0]
  snt_len = model_output.shape[1]
  hidden_size = model_output.shape[2]

  model_output = model_output.reshape(-1, hidden_size)
  true_trg = true_trg.reshape(-1)

  loss_mod = nn.CrossEntropyLoss(weight=weight, ignore_index=0)## PAD = 0
  loss = loss_mod(model_output, true_trg)



  #z = torch.LongTensor(model_output[true_trg!=1045].shape[0]).fill_(1045).to(dev)
  #neg_loss = -0.5*F.nll_loss(nn.functional.log_softmax(model_output[true_trg!=1045]), z, reduction='mean')

  return loss

# %%
from tqdm.auto import tqdm

def train_step(batch_idx, batch):
  pair_batch, segment_batch, response_batch = batch
  pair_batch = pair_batch.to(dev)
  segment_batch = segment_batch.to(dev)
  response_batch = response_batch.to(dev)
  model_output = model(pair_batch, segment_batch, response_batch)
  #kwargs = {'easy_training':4}
  loss = mahdi_loss(model_output, response_batch)
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()
  scheduler.step()
  del pair_batch
  del segment_batch
  del response_batch
  return loss.item()

def valid_step(batch_idx, batch):
  with torch.no_grad():
    pair_batch, segment_batch, response_batch = batch
    pair_batch = pair_batch.to(dev)
    segment_batch = segment_batch.to(dev)
    response_batch = response_batch.to(dev)
    model_output = model(pair_batch, segment_batch, response_batch)
    loss = mahdi_loss(model_output, response_batch)
    del pair_batch
    del segment_batch
    del response_batch
    return loss.item()

def valid_loop(valid_loader):
  total_loss = 0
  model.eval()
  for batch_idx, batch in tqdm(enumerate(valid_loader),  total=len(valid_loader), leave=False):
    total_loss += valid_step(batch_idx, batch)
  
  print("temperature is 1:")
  kwargs = {'num_beams':8,'num_return_sequences':8,'temperature':1,
            'no_repeat_ngram_size':3}
  #kwargs = {}
  valid_inference(**kwargs)

  print("most greedy sentence:")
  kwargs = {
          'num_return_sequences':1,'temperature':1, 'max_length':50, 'early_stopping':True,
          'no_repeat_ngram_size':3,
          'top-k':1
          }
  #kwargs = {}
  valid_inference(**kwargs)

  # print("temperature is 2:")
  # kwargs = {'num_beams':16,'num_return_sequences':16,'temperature':2}
  # valid_inference(**kwargs)


  model.train()
  return total_loss / len(valid_loader)

def valid_inference(idx=500, **kwargs):
  hk_pair =  train_dataset[idx]['input_pair'].to(dev)
  hk_segment = train_dataset[idx]['input_pair_segments'].to(dev)
  response = train_dataset[idx]['response'].to(dev)
  generateds = model.generate(hk_pair, hk_segment, **kwargs)
  print("pair is: ",enc_tokenizer.decode(hk_pair))
  print("response is: ",dec_tokenizer.decode(response))
  for generated in generateds:
    print("model says: ",dec_tokenizer.decode(generated))

# %%
new_learning = True
if new_learning:
  # optimizer = NoamOpt(128, 1, 2000,
  #           torch.optim.Adam(model.parameters(), lr=0, betas=(0.9, 0.98), eps=1e-9))
  model_dir = "/content/drive/My Drive/Thesis/phase-3/Models/Montazeri/L-2-2_H-128_Plus"
  step = 0
  log_list = []

# %%
## if continue learning:
#!wget -q https://github.com/mmsamiei/MS-Thesis-Phase2/raw/master/Models/hashemi_16000steps.model
model_dir = "/content/drive/My Drive/Thesis/phase-3/Models/Montazeri/L-6-6_H-256_Plus"
checkpoint = torch.load(model_dir+'/montazeri_60009steps.model')
step = checkpoint['log_list'][-1]['step']
model.load_state_dict(checkpoint['model_state_dict'])
optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
optimizer._step = step
log_list = checkpoint['log_list']
best_valid = checkpoint['best_valid']
new_learning = False
print(step)
# Out:
# 5999

# %%
from tqdm.auto import tqdm

MAX_STEP = 20000
STEP_SAVE = 1000
STEP_CHECK = 500
step_num = step + 1
best_valid = 99999999
log_list = log_list ### Check if new learning or not

print(step_num)

while step_num <= MAX_STEP:
  model.train()
  for batch_idx, batch in tqdm(enumerate(iter(train_loader)), total=len(train_loader), leave=False):
    step_loss = train_step(batch_idx, batch)
    log = {'step':step_num, 'train_loss':step_loss}

    if(step_num % STEP_CHECK == 0):
      valid_error = valid_loop(valid_loader)
      train_losses = [step['train_loss'] for step in log_list[-100:]]
      avg_train_loss = sum(train_losses) / len(train_losses)
      print("train Loss rate: {} at step {}".format(avg_train_loss, step_num))  
      print("valid Loss rate: {} at step {}".format(valid_error, step_num))  
      log['valid_loss'] = valid_error

      if valid_error < best_valid:
        best_valid = valid_error
        torch.save({
            'model_state_dict': model.state_dict(),
            'log_list': log_list,
            'optimizer_state_dict': optimizer.state_dict(),
            'best_valid': best_valid
            }, model_dir+'/montazeri_best_valid.model'.format(step_num))

    log_list.append(log)

    if(step_num % STEP_SAVE == 0):
      torch.save({
            'model_state_dict': model.state_dict(),
            'log_list': log_list,
            'optimizer_state_dict': optimizer.state_dict(),
            'best_valid': best_valid
            }, model_dir+'/montazeri_{}steps.model'.format(step_num))
    step_num += 1
# Out:
# 1
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure it's a lot of a lot. i've been been
# model says:  [CLS] i'm not sure it's a lot of a lot. i've been a
# model says:  [CLS] i'm not sure it's a lot of a lot lot of the lot of lot
# model says:  [CLS] i'm not sure it's a lot of a lot. i've been seen
# model says:  [CLS] i'm not sure it's a lot of a lot lot of the city of the
# model says:  [CLS] i'm not sure it's a lot of a lot lot of the world. i
# model says:  [CLS] i'm not sure it's a lot of lot of a lot lot of the lot
# model says:  [CLS] i'm not sure it's a lot of a lot lot of lot of the lot
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm sure sure that is a lot of the world. i've been been a lot. [SEP]
# train Loss rate: 5.476656160354614 at step 500
# valid Loss rate: 5.336500086103167 at step 500
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure that's not not sure it. it's a lot of
# model says:  [CLS] i'm not sure that's not not sure, but it's a lot of
# model says:  [CLS] i'm not sure that's not not sure. it's a lot of the
# model says:  [CLS] i'm not sure that's not not sure it's a lot of a lot
# model says:  [CLS] i'm not sure that's not not sure. it's a lot of a
# model says:  [CLS] i'm not sure that's not not sure. it's a lot of my
# model says:  [CLS] i'm not sure that's not not sure it's a lot of the world
# model says:  [CLS] i'm not sure that's not not sure, but it's a lot.
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i love the most popular popular, it is a popular in the world. it is the largest largest city. [SEP]
# train Loss rate: 4.991537199020386 at step 1000
# valid Loss rate: 4.962627043042864 at step 1000
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure that's not sure, but it's. [SEP] [SEP] [SEP]
# model says:  [CLS] i'm not sure that's not sure, but it's a lot of the
# model says:  [CLS] i'm not sure, but it's a lot of the world. [SEP] [SEP] [SEP]
# model says:  [CLS] i'm not sure, but it's a lot of a lot. [SEP] [SEP] [SEP]
# model says:  [CLS] i'm not sure that's not not sure. [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] i'm not sure that's not sure, but it's sure. [SEP] [SEP]
# model says:  [CLS] i'm not sure that's not sure, but it's a lot of a
# model says:  [CLS] i'm not sure. it's not sure that's a lot of a lot
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i love the most popular popular in the world. [SEP]
# train Loss rate: 4.7210067653656 at step 1500
# valid Loss rate: 4.757579483304705 at step 1500
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] do you like a lot of cars. [SEP] [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] do you have a lot of cars. [SEP] [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] yes, it is a lot of transportation. [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] do you like a lot of transportation. [SEP] [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] yes, it is a lot of the world. [SEP] [SEP] [SEP]
# model says:  [CLS] yes, it is a lot of transportation and transportation. [SEP] [SEP]
# model says:  [CLS] yes, it is a lot of the world [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] yes, it is a lot of transportation, and transportation. [SEP]
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i love the honda is a honda. [SEP]
# train Loss rate: 4.737818546295166 at step 2000
# valid Loss rate: 4.749586868286133 at step 2000
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure. it's not sure, but it is a lot of the
# model says:  [CLS] i'm not sure. it's not sure, but i've been a lot
# model says:  [CLS] i'm not sure. it's a lot of transportation, but i've been
# model says:  [CLS] i'm not sure. it's not sure, but it is a lot of a
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i've
# model says:  [CLS] i'm not sure. it's not sure, but i've never been a
# model says:  [CLS] i'm not sure. it's not sure, but i've never been to
# model says:  [CLS] i'm not sure. it's a lot of transportation, but i've never
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure, but i've been a lot of the world. i'd like a lot like a car. [SEP]
# train Loss rate: 4.642486715316773 at step 2500
# valid Loss rate: 4.6656969547271725 at step 2500
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure. it's a lot of a lot. it is a lot
# model says:  [CLS] i'm not sure, but it's a lot of transportation. it is a lot
# model says:  [CLS] i'm not sure, but it's a lot of cars. it is a lot
# model says:  [CLS] i'm not sure. it's a lot of transportation, but i've been
# model says:  [CLS] i'm not sure. it's not sure, but i've been a lot
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i've
# model says:  [CLS] i'm not sure. it's a lot of transportation, but i've never
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i have a
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure, but i've been a lot of a lot. [SEP]
# train Loss rate: 4.443685574531555 at step 3000
# valid Loss rate: 4.500323745182582 at step 3000
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure. it's a lot of transportation. [SEP] [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] i'm not sure, but it's a lot of transportation. [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] i'm not sure, but it's a lot of cars. [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] i'm not sure, but it's a lot of transportation and transportation. [SEP] [SEP]
# model says:  [CLS] i'm not sure. it's a lot of transportation and transportation. [SEP] [SEP] [SEP]
# model says:  [CLS] i'm not sure, but it's a lot of transportation, and transportation. [SEP]
# model says:  [CLS] i'm not sure. it's a lot of transportation, and transportation. [SEP] [SEP]
# model says:  [CLS] i'm not sure. it's a lot of transportation and transportation, and transportation.
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i love the road, i love to ride a lot of the road. [SEP]
# train Loss rate: 4.250633599758149 at step 3500
# valid Loss rate: 4.434644341468811 at step 3500
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i am not sure, but it is a lot of transportation. [SEP]
# model says:  [CLS] yes, it is a lot of transportation. [SEP] [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] i am not sure. it is a lot of transportation. [SEP] [SEP]
# model says:  [CLS] i am not sure, but i have a lot of transportation. [SEP]
# model says:  [CLS] yes, it is a lot of transportation and transportation. [SEP] [SEP] [SEP]
# model says:  [CLS] it is a lot of transportation. [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] i am not sure, but it is a lot of vehicles. [SEP]
# model says:  [CLS] i am not sure, but it is a lot of traffic. [SEP]
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i love the transportation is a lot of transportation. [SEP]
# train Loss rate: 4.02991459608078 at step 4000
# valid Loss rate: 4.420291938100543 at step 4000
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure, but i don't know that it's a lot of
# model says:  [CLS] i'm not sure, but i don't think it's a lot of the
# model says:  [CLS] i'm not sure, but i don't think it's a lot of a
# model says:  [CLS] i'm not sure, but i don't think it's a lot of transportation
# model says:  [CLS] i'm not sure, but i don't think it's a lot of traffic
# model says:  [CLS] i'm not sure, but i don't think it's a lot of cars
# model says:  [CLS] i'm not sure, but i don't think it's a lot of vehicles
# model says:  [CLS] i'm not sure, but i don't think it's a lot of fun
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure, but i've been a lot of a lot, but it's a lot like a lot. i'd like to be a lot that is a lot to be used to be made by a lot for
# train Loss rate: 4.428107523918152 at step 4500
# valid Loss rate: 4.503042616162982 at step 4500
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure, but it's a lot of transportation. it is a lot
# model says:  [CLS] i'm not sure. it's a lot of transportation, but it is a lot
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i've
# model says:  [CLS] i'm not sure. it's a lot of transportation, but i've been
# model says:  [CLS] i'm not sure, but it's a lot of transportation. i've been
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i have a
# model says:  [CLS] i'm not sure. it's a lot of transportation, but i've never
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i can be
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure, but i've been to be a lot of a lot like a lot. [SEP]
# train Loss rate: 4.229375591278076 at step 5000
# valid Loss rate: 4.3575838157108855 at step 5000
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure, but it's a lot of transportation. [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] i'm not sure, but it's a lot of transportation and transportation. [SEP] [SEP]
# model says:  [CLS] i'm not sure. it's a lot of transportation. [SEP] [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] i'm not sure, but it's a lot of transportation, and transportation. [SEP]
# model says:  [CLS] i'm not sure. it's a lot of transportation and transportation. [SEP] [SEP] [SEP]
# model says:  [CLS] i'm not sure, but it's a lot of transportation. it is a lot
# model says:  [CLS] i'm not sure. it's a lot of transportation, but it is a lot
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i've
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i love the transportation is a lot of transportation, and transportation, transportation, or transportation, etc. [SEP]
# train Loss rate: 4.03378306388855 at step 5500
# valid Loss rate: 4.284146635872977 at step 5500
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i am not sure, but it is a lot of transportation. [SEP] [SEP] [SEP]
# model says:  [CLS] i think it's a lot of transportation. [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] i think it's a lot of transportation and transportation. [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] i am not sure, but it is a lot of transportation and transportation. [SEP]
# model says:  [CLS] i think it's a lot of vehicles. [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] i am not sure, but it is a lot of traffic traffic. [SEP] [SEP]
# model says:  [CLS] i think it's a lot of transportation. it is a lot. [SEP]
# model says:  [CLS] i am not sure, but it is a lot of transportation [SEP] [SEP] [SEP] [SEP]
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i like to make a lot of transportation. [SEP]
# train Loss rate: 3.828205029964447 at step 6000
# valid Loss rate: 4.280675990240915 at step 6000
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure. it's a lot of transportation. [SEP] [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] i'm not sure, but it's a lot of transportation. [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] i'm not sure. [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] i'm not sure. it's a lot of transportation, but it is a lot
# model says:  [CLS] i'm not sure, but it's a lot of transportation. it is a lot
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i've
# model says:  [CLS] i'm not sure. it's a lot of transportation [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] i'm not sure. it's a lot of vehicles. [SEP] [SEP] [SEP] [SEP] [SEP]
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] it is a lot of transportation, but it is so much. [SEP]
# train Loss rate: 4.403620011806488 at step 6500
# valid Loss rate: 4.262276485988072 at step 6500
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure, but i don't know that it's a lot of
# model says:  [CLS] i'm not sure, but i don't think it's a lot of transportation
# model says:  [CLS] i'm not sure, but i don't think it's a lot of a
# model says:  [CLS] i'm not sure, but i don't think it's a lot of traffic
# model says:  [CLS] i'm not sure, but i don't think it's a lot of the
# model says:  [CLS] i'm not sure, but i don't think it's a lot of rail
# model says:  [CLS] i'm not sure, but i don't think it's a lot of roads
# model says:  [CLS] i'm not sure, but i don't think it's a lot of vehicles
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure, but i've been a lot of transportation, but it is a lot like a lot. [SEP]
# train Loss rate: 4.123243539333344 at step 7000
# valid Loss rate: 4.305620241165161 at step 7000
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure, but it's a lot of transportation. it is a lot
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i've
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i think it
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i have a
# model says:  [CLS] i'm not sure, but it's a lot of roads. it is a lot
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i do not
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i do like
# model says:  [CLS] i'm not sure, but it's a lot of transportation. it can be used
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i think it is a lot of transportation, but i'm not sure. it's a lot. [SEP]
# train Loss rate: 3.9039529085159304 at step 7500
# valid Loss rate: 4.231070940835135 at step 7500
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] yes, it's a lot of transportation. [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] i think it's a lot of transportation. [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] i think it's a lot of transportation, but it is easier. [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] i think it's a lot of transportation, but it is easier to make it. [SEP]
# model says:  [CLS] i think it's a lot of transportation, but it is easier to make it easier.
# model says:  [CLS] i think it's a lot of transportation, but it can be made in the uk.
# model says:  [CLS] i think it's a lot of transportation, but it is easier to make it easier to
# model says:  [CLS] i think it's a lot of transportation, but it can be made in the uk [SEP]
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i think it is a lot of transportation, but it is really easy to make it. [SEP]
# train Loss rate: 3.70853524684906 at step 8000
# valid Loss rate: 4.196980602400643 at step 8000
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] yes, it is a lot of transportation. [SEP] [SEP] [SEP]
# model says:  [CLS] yes, it is a great form of transportation. [SEP] [SEP]
# model says:  [CLS] yes, it is a lot of roads. [SEP] [SEP] [SEP]
# model says:  [CLS] yes, it is a lot of transportation and transportation. [SEP]
# model says:  [CLS] yes, it is a lot of transportation [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] yes, it is a lot of motorized vehicles. [SEP] [SEP]
# model says:  [CLS] yes, it is a lot of transportation and roads. [SEP]
# model says:  [CLS] yes, it is a great form of transportation [SEP] [SEP] [SEP]
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] yes, it is a great vehicle [SEP]
# train Loss rate: 3.862701189517975 at step 8500
# valid Loss rate: 4.261539513724191 at step 8500
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure, but i don't know that it's a lot of
# model says:  [CLS] i'm not sure, but i don't think it's a lot of transportation
# model says:  [CLS] i'm not sure, but i don't think it's a lot of traffic
# model says:  [CLS] i'm not sure, but i don't think it's a lot of roads
# model says:  [CLS] i'm not sure, but i don't think it's a lot of a
# model says:  [CLS] i'm not sure, but i don't know that it's hard to make
# model says:  [CLS] i'm not sure, but i don't think it's a lot of rail
# model says:  [CLS] i'm not sure, but i don't think it's a lot of vehicles
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure, but i've been to a lot of transportation, but it is a lot to be a lot like a lot. [SEP]
# train Loss rate: 4.07464704990387 at step 9000
# valid Loss rate: 4.2605920451028005 at step 9000
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i think it
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i've
# model says:  [CLS] i'm not sure, but it's a lot of transportation. it is a lot
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i am not
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i do like
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i do not
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i have a
# model says:  [CLS] i'm not sure, but it's a lot of transportation, but i think they
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i think it is a lot of transportation, but i'm not sure, but it is easier to make it. [SEP]
# train Loss rate: 3.8413146209716795 at step 9500
# valid Loss rate: 4.178943194661822 at step 9500
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] yes, it's a lot of transportation, but it can be used on the road.
# model says:  [CLS] yes, it's a lot of transportation, but it can be used on the line.
# model says:  [CLS] yes, it's a lot of transportation, but it can be made in the uk.
# model says:  [CLS] yes, it's a lot of transportation, but it can be used on a line of
# model says:  [CLS] yes, it's a lot of transportation, but it can be used on a line.
# model says:  [CLS] yes, it's a lot of transportation, but it can be made in the uk [SEP]
# model says:  [CLS] yes, it's a lot of transportation, but it can be used in the uk.
# model says:  [CLS] yes, it's a lot of transportation, but it can be used on the line of
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] yes, it is a lot of transportation, but it is usually a lot that is a line of roads [SEP]
# train Loss rate: 3.6407999181747437 at step 10000
# valid Loss rate: 4.15630715233939 at step 10000
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] it's a lot of transportation. [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] it's a lot of transportation. it can be made by roads. [SEP] [SEP]
# model says:  [CLS] it's a lot of transportation. it can be used on the line. [SEP]
# model says:  [CLS] it's a lot of transportation. it can be made by roads [SEP] [SEP] [SEP]
# model says:  [CLS] it's a lot of transportation. it can be used on the line [SEP] [SEP]
# model says:  [CLS] it's a lot of transportation. it can be used on the road. [SEP]
# model says:  [CLS] it's a lot of transportation. it can be used on a line. [SEP]
# model says:  [CLS] it's a lot of transportation. it can be used on the road [SEP] [SEP]
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] it is a lot of transportation. it is also a lot [SEP]
# train Loss rate: 3.344096348285675 at step 10500
# valid Loss rate: 4.168157502583095 at step 10500
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure, but i don't know that it's a lot of
# model says:  [CLS] i'm not sure, but i don't know, but it's a lot
# model says:  [CLS] i'm not sure, but i don't know, but it's hard to
# model says:  [CLS] i'm not sure, but i don't think it's a lot of transportation
# model says:  [CLS] i'm not sure, but i don't think it's a lot of roads
# model says:  [CLS] i'm not sure, but i don't know that it's hard to make
# model says:  [CLS] i'm not sure, but i don't think it's a lot of rail
# model says:  [CLS] i'm not sure, but i don't think it's a lot of vehicles
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure, but i've been to a lot of transportation, but it is a lot to be a lot that is a line of a lot. [SEP]
# train Loss rate: 4.064255180358887 at step 11000
# valid Loss rate: 4.274824840681894 at step 11000
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] yes, it's a lot of transportation, but i'm not sure, but it
# model says:  [CLS] yes, it's a lot of transportation, but i'm not sure if you can
# model says:  [CLS] yes, it's a lot of transportation, but i'm not sure. it is
# model says:  [CLS] yes, it's a lot of transportation, but i'm not sure, but they
# model says:  [CLS] yes, it's a lot of transportation, but i'm not sure. it '
# model says:  [CLS] yes, it's a lot of transportation, but i'm not not sure, but
# model says:  [CLS] yes, it's a lot of transportation, but i'm not sure but it is
# model says:  [CLS] yes, it's a lot of transportation, but i'm not sure, but the
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i think it is a lot of transportation, but i have a lot to make a lot like a lot. [SEP]
# train Loss rate: 3.813883924484253 at step 11500
# valid Loss rate: 4.186686859812055 at step 11500
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] it's a lot of transportation, but it can be used on the line of roads.
# model says:  [CLS] it's a lot of transportation, but it can be used on a line of roads.
# model says:  [CLS] it's a lot of transportation, but it can be made by roads and roads. [SEP]
# model says:  [CLS] it's a lot of transportation, but it can be used on the road. [SEP] [SEP]
# model says:  [CLS] it's a lot of transportation, but it can be used on roads. it is a
# model says:  [CLS] it's a lot of transportation, but it can be used on a line of a line
# model says:  [CLS] it's a lot of transportation, but it can be used on the line of the road
# model says:  [CLS] it's a lot of transportation, but it can be used on the line of the line
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i think it is a lot of transportation, but i think they are usually a lot. [SEP]
# train Loss rate: 3.597584252357483 at step 12000
# valid Loss rate: 4.130659372465951 at step 12000
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] yes, it can be used on the road. it's a lot of roads. [SEP]
# model says:  [CLS] yes, it can be used on the line of roads and roads. [SEP] [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] yes, it can be used on the line of roads. [SEP] [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] yes, it can be used on the road. it's hard to make it. [SEP]
# model says:  [CLS] yes, it can be used on the line of the road. [SEP] [SEP] [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] yes, it can be used on the road. it's so cool. [SEP] [SEP] [SEP]
# model says:  [CLS] yes, it can be used on the road. it's a lot of transportation. [SEP]
# model says:  [CLS] yes, it can be used on the road. it's on the line. [SEP] [SEP]
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] yes, it is a lot of transportation, but it is easier to make it. [SEP]
# train Loss rate: 3.3656127882003783 at step 12500
# valid Loss rate: 4.118029890741621 at step 12500
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# ...
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i think it is a lot of transportation, but i think they are usually on the line of the road. [SEP]
# train Loss rate: 3.5761413836479186 at step 16000
# valid Loss rate: 4.107387689181737 at step 16000
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] yes, rail vehicles have a lot of motorized vehicles. it's hard to make it.
# model says:  [CLS] yes, rail vehicles have a lot of rail vehicles. it's hard to make it.
# model says:  [CLS] yes, rail vehicles have a lot of motorized vehicles. it's hard to ride. [SEP]
# model says:  [CLS] yes, rail vehicles have a lot of rail vehicles. it's hard to ride. [SEP]
# model says:  [CLS] yes, rail vehicles have a lot of motorized vehicles. it's hard to go to the
# model says:  [CLS] yes, rail vehicles have a lot of rail vehicles. it's hard to go to the
# model says:  [CLS] yes, rail vehicles have a lot of motorized vehicles. it's hard to go to a
# model says:  [CLS] yes, rail vehicles have a lot of motorized vehicles. it's hard to make a lot
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] yes, rail transport is a line of rail vehicles. it is a lot of roads. [SEP]
# train Loss rate: 3.3415346145629883 at step 16500
# valid Loss rate: 4.06978189604623 at step 16500
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] yes, rail vehicles are usually made by rail vehicles. [SEP] [SEP] [SEP]
# model says:  [CLS] yes, rail vehicles are usually made by roads and roads. [SEP] [SEP]
# model says:  [CLS] yes, rail vehicles are usually on the line of roads. [SEP] [SEP]
# model says:  [CLS] yes, rail vehicles are made by rail vehicles. [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] yes, rail vehicles are usually on the line of rail vehicles. [SEP]
# model says:  [CLS] yes, rail vehicles are usually made by roads. [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] yes, rail vehicles are usually on the road. [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] yes, rail vehicles are usually used to transport. [SEP] [SEP] [SEP] [SEP]
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] it is a sub - - line of rail vehicles. [SEP]
# train Loss rate: 3.0298804593086244 at step 17000
# valid Loss rate: 4.081568353516715 at step 17000
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure, but i don't know, but it's hard to
# model says:  [CLS] i'm not sure, but i don't know that it's a lot of
# model says:  [CLS] i'm not sure, but i don't know, but it's a lot
# model says:  [CLS] i'm not sure, but i don't know that it's hard to get
# model says:  [CLS] i'm not sure, but i don't know, but it's basically a
# model says:  [CLS] i'm not sure, but i don't know that it's hard to be
# model says:  [CLS] i'm not sure, but i don't know that it's hard to make
# model says:  [CLS] i'm not sure, but i don't know, but it's just a
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure, but i've never been to a rail line, but it's a lot of roads, but they are usually a lot to be a lot. [SEP]
# train Loss rate: 3.869797444343567 at step 17500
# valid Loss rate: 4.210881836073739 at step 17500
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] it's a lot of transportation, but it can be used on roads, but they are
# model says:  [CLS] it's a lot of transportation, but it can be used on roads and roads. it
# model says:  [CLS] it's a lot of transportation, but it can be used on roads and roads. i
# model says:  [CLS] it's a lot of transportation, but it can be used on roads and roads, but
# model says:  [CLS] it's a lot of transportation, but it can be used on roads on the road.
# model says:  [CLS] it's a lot of transportation, but it can be used on roads and roads. they
# model says:  [CLS] it's a lot of transportation, but it can be made by roads and roads. it
# model says:  [CLS] it's a lot of transportation, but it can be made by roads and roads. i
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i think it is a lot of transportation, but i think they are usually on the road. it is usually a line of roads. [SEP]
# train Loss rate: 3.5895992970466613 at step 18000
# valid Loss rate: 4.105722989354815 at step 18000
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] it's a lot of transportation, but it can be used on roads and roads. [SEP]
# model says:  [CLS] it's a lot of transportation, but it can be made by roads and roads. [SEP]
# model says:  [CLS] it's a lot of transportation, but it can be used on roads. it is a
# model says:  [CLS] it's a lot of transportation, but it can be made by roads. it is a
# model says:  [CLS] it's a lot of transportation, but it can be used on roads. [SEP] [SEP] [SEP]
# model says:  [CLS] it's a lot of transportation, but it can be made by roads. [SEP] [SEP] [SEP]
# model says:  [CLS] it's a lot of transportation, but it can be used on roads and roads [SEP] [SEP]
# model says:  [CLS] it's a lot of transportation, but it can be used on roads. it is really
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i think it is a lot of transportation, but i do not want to ride a lot. [SEP]
# train Loss rate: 3.3391503262519837 at step 18500
# valid Loss rate: 4.050015783309936 at step 18500
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] it's hard to stop roads and roads. it can be made by roads. [SEP] [SEP]
# model says:  [CLS] it's hard to stop roads and roads. it is hard to make it. [SEP] [SEP]
# model says:  [CLS] it's hard to stop roads and roads. it is hard to get on the road.
# model says:  [CLS] it's hard to stop roads and roads. it can be on roads. [SEP] [SEP] [SEP]
# model says:  [CLS] it's hard to stop roads and roads. it is a line of roads. [SEP] [SEP]
# model says:  [CLS] it's hard to stop roads and roads. it can be made by roads [SEP] [SEP] [SEP]
# model says:  [CLS] it's hard to stop roads and roads. it can be dangerous. [SEP] [SEP] [SEP] [SEP]
# model says:  [CLS] it's hard to stop roads and roads. it is hard to be on roads. [SEP]
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] yes, rail transport is a line of rail vehicles. it is a compact vehicle [SEP]
# train Loss rate: 3.0928748178482057 at step 19000
# valid Loss rate: 4.050375904355731 at step 19000
# HBox(children=(FloatProgress(value=0.0, max=649.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] rail transport is a motorized vehicle [SEP] [SEP]
# model says:  [CLS] rail vehicles are a motorized vehicle [SEP] [SEP]
# model says:  [CLS] rail vehicles are motorized vehicles [SEP] [SEP] [SEP]
# model says:  [CLS] rail vehicles are motorized bicycles [SEP] [SEP] [SEP]
# model says:  [CLS] rail transport is a motorized vehicle. [SEP]
# model says:  [CLS] rail vehicles are motorized vehicles. [SEP] [SEP]
# model says:  [CLS] rail rail transport is a motorized vehicle [SEP]
# model says:  [CLS] rail rail vehicles are a motorized vehicle [SEP]
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] rail vehicles are usually called tramping [SEP]
# train Loss rate: 3.7003043913841247 at step 19500
# valid Loss rate: 4.288138852800642 at step 19500
# HBox(children=(FloatProgress(value=0.0, max=70.0), HTML(value='')))
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# temperature is 1:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure, but i don't know that it's a lot of
# model says:  [CLS] i'm not sure, but i don't know that it's hard to get
# model says:  [CLS] i'm not sure, but i don't know that it's really hard to
# model says:  [CLS] i'm not sure, but i don't know that it's hard to make
# model says:  [CLS] i'm not sure, but i don't know that it's hard to be
# model says:  [CLS] i'm not sure, but i don't know that it's hard to ride
# model says:  [CLS] i'm not sure, but i don't know that it's hard to stop
# model says:  [CLS] i'm not sure, but i don't really want to stop roads, but they
# most greedy sentence:
# pair is:  [CLS] rail transport [SEP] i believe rail transport is the safest means of transport [SEP] why do you feel that way? [SEP] in contrast to road transport, where vehicles run on a prepared flat surface, rail vehicles ( rolling stock ) are directionally guided by the tracks on which they run. [SEP]
# response is:  [CLS] rail vehicles use tracks and not roads [SEP]
# model says:  [CLS] i'm not sure, but i've never been to a rail line, but it's a lot of roads. [SEP]
# train Loss rate: 3.6169250774383546 at step 20000
# valid Loss rate: 4.112043881416321 at step 20000

# %%
kwargs = {'num_beams':4,
          'num_return_sequences':1,'temperature':1, 'max_length':50, 'early_stopping':True,
          'no_repeat_ngram_size':1,
          #'top-k':3,
          #'top-p':0.95,
          #'do_sample':True
          }
#kwargs = {}
valid_inference(idx=1202, **kwargs)
# Out:
# Setting `pad_token_id` to 102 (first `eos_token_id`) to generate sequence
# pair is:  [CLS] rose [SEP] most species of roses are native to asia [SEP] i love roses they are my favorite what colors do they have in asia. [SEP] flowers vary in size and shape and are usually large and showy, in colours ranging from white through yellows and reds. [SEP]
# response is:  [CLS] they have colors ranging from white to red [SEP]
# model says:  [CLS] i'm not sure, but they have a lot of different colors. it can vary in the size and shape ranging from yellow or white - colored colours to come with red!

# %%
kwargs = {'num_beams':8,
          'num_return_sequences':4,'temperature':1,'min_length':30,
          'max_length':100, 'early_stopping':True,
          'no_repeat_ngram_size':1,
          #'top-k':1,
          #'do_sample':True
          }
history = "Tell me about your best friend! [SEP] my best friend is habibi [SEP] What is his religion? [SEP]"
knowledge = "habibi is a muslim boy"
history_tokenized = enc_tokenizer.encode(history)
knowledge_tokenized = enc_tokenizer.encode(knowledge)
generateds = model.generate(torch.LongTensor(history_tokenized + knowledge_tokenized).to(dev),
               torch.LongTensor([0]*len(history_tokenized) + [1]*len(knowledge_tokenized)).to(dev),
               **kwargs)
dec_tokenizer.batch_decode(generateds)
# Out:
# ["[CLS] haha, it is a social deal with the name of na - he's not sure how many people are talking about him and know. [SEP] [SEP]",
#  "[CLS] haha, it is a social deal with the name of na - he's not sure how many people are talking about him lorriers [SEP] [SEP]",
#  "[CLS] haha, it is a social deal with the name of na - he's not sure how many people are talking about him lorriers ) [SEP]",
#  "[CLS] haha, it is a social deal with the name of na - he's not sure how many people are talking about him lon. [SEP] [SEP]"]

# %%
import numpy as np
logging.getLogger("transformers").setLevel(logging.ERROR)

model.eval()

f_scores = []
for i in tqdm(range(len(test_seen_dataset))):
  kwargs = {'num_beams':1,
            'num_return_sequences':1,'temperature':1, 'max_length':50, 'early_stopping':True,
            'no_repeat_ngram_size':1,
            #'top-k':1
            }
  #kwargs = {}
  hk_pair =  test_seen_dataset[i]['input_pair'].to(dev)
  hk_segment = test_seen_dataset[i]['input_pair_segments'].to(dev)
  response = test_seen_dataset[i]['response'].to(dev)
  generateds = model.generate(hk_pair, hk_segment, **kwargs)
  generateds = generateds.squeeze(0).cpu().numpy()
  response = response.squeeze(0).cpu().numpy()
  intersections = np.intersect1d(generateds, response)
  recall = len(intersections) / len(response)
  precision = len(intersections) / len(generateds)
  f1_score = 2 * (precision * recall) / (precision + recall)
  f_scores.append(f1_score)
  if i % 100 == 0 :
    print( sum(f_scores) / len(f_scores))
print( sum(f_scores) / len(f_scores))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2224.0), HTML(value='')))
# 0.46153846153846156
# 0.4501973145386566
# 0.451918002076293
# 0.4357974896489864
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-6497dac72821> in <module>()
#      15   hk_segment = test_seen_dataset[i]['input_pair_segments'].to(dev)
#      16   response = test_seen_dataset[i]['response'].to(dev)
# ---> 17   generateds = model.generate(hk_pair, hk_segment, **kwargs)
#      18   generateds = generateds.squeeze(0).cpu().numpy()
#      19   response = response.squeeze(0).cpu().numpy()
#
# <ipython-input-17-9ae68dde2133> in generate(self, encoder_input, segments_tensors, **kwargs)
#      33     generated = model.seq2seq.generate(input_ids=encoder_input,
#      34         decoder_start_token_id=101,bos_token_id=101,
# ---> 35         eos_token_id=102, **kwargs)
#      36
#      37     #### generated = [1, len]
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      13         def decorate_context(*args, **kwargs):
#      14             with self:
# ---> 15                 return func(*args, **kwargs)
#      16         return decorate_context
#      17
#
# /usr/local/lib/python3.6/dist-packages/transformers/generation_utils.py in generate(self, input_ids, max_length, min_length, do_sample, early_stopping, num_beams, temperature, top_k, top_p, repetition_penalty, bad_words_ids, bos_token_id, pad_token_id, eos_token_id, length_penalty, no_repeat_ngram_size, num_return_sequences, attention_mask, decoder_start_token_id, use_cache, **model_specific_kwargs)
#     383             encoder = self.get_encoder()
#     384
# --> 385             encoder_outputs: tuple = encoder(input_ids, attention_mask=attention_mask, token_type_ids=model_specific_kwargs.pop('token_type_ids', None))
#     386
#     387         # Expand input ids if num_beams > 1 or num_return_sequences > 1
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/transformers/modeling_bert.py in forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, output_attentions, output_hidden_states, return_tuple)
#     797             output_attentions=output_attentions,
#     798             output_hidden_states=output_hidden_states,
# --> 799             return_tuple=return_tuple,
#     800         )
#     801         sequence_output = encoder_outputs[0]
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/transformers/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, output_attentions, output_hidden_states, return_tuple)
#     458                     encoder_hidden_states,
#     459                     encoder_attention_mask,
# --> 460                     output_attentions,
#     461                 )
#     462             hidden_states = layer_outputs[0]
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/transformers/modeling_bert.py in forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, output_attentions)
#     407
#     408         intermediate_output = self.intermediate(attention_output)
# --> 409         layer_output = self.output(intermediate_output, attention_output)
#     410         outputs = (layer_output,) + outputs
#     411         return outputs
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     538         return result
#     539
# --> 540     def __call__(self, *input, **kwargs):
#     541         for hook in self._forward_pre_hooks.values():
#     542             result = hook(self, input)
#
# KeyboardInterrupt:
